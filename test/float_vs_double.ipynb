# %%
import matplotlib.pyplot as plt
import math

# %%
inpFloat, quadFloat = list(), list()
# with open('iofiles/float_inphase_quadrature_output_gmsk_modulate.txt') as f: 
with open('/home/giannis/Desktop/playground/outputs/new_float.txt') as f: 
    lines = f.readlines()
    for i in range(0, len(lines), 3): 
        line1 = lines[i].strip()
        line2 = lines[i + 1].strip()
        inpFloat.append(float(line1))
        quadFloat.append(float(line2))

# %%
inpDouble, quadDouble = list(), list()
with open('iofiles/double_inphase_quadrature_output_gmsk_modulate.txt') as d:
    lines = d.readlines()
    for i in range(0, len(lines), 3): 
        line1 = lines[i].strip()
        line2 = lines[i + 1].strip()
        inpDouble.append(float(line1))
        quadDouble.append(float(line2))

# %%
inpX86float, quadX86float = list(), list()
with open('iofiles/gmsk_float_x86_output.txt') as fX86:
    lines = fX86.readlines()
    for i in range(0, len(lines), 3): 
        line1 = lines[i].strip()
        line2 = lines[i + 1].strip()
        inpX86float.append(float(line1))
        quadX86float.append(float(line2))

# %%
inpX86double, quadX86double = list(), list()
with open('iofiles/gmsk_float_x86_output.txt') as dX86:
    lines = dX86.readlines()
    for i in range(0, len(lines), 3): 
        line1 = lines[i].strip()
        line2 = lines[i + 1].strip()
        inpX86double.append(float(line1))
        quadX86double.append(float(line2))

# %%
# float inPhase vs Quadrature graph
plt.plot(inpFloat, quadFloat)
plt.grid()
plt.show()

# %%
# double inPhase vs Quadrature graph
plt.plot(inpDouble, quadDouble)
plt.grid()
plt.show()

# %%
# x86 inPhase vs Quadrature graph
plt.plot(inpX86float, quadX86float)
plt.grid()
plt.show()

# %%
# x86 inPhase vs Quadrature graph double
plt.plot(inpX86double, quadX86double)
plt.grid()
plt.show()

# %%
# float inPhase 
plt.plot(inpFloat[:500], 'r-')
plt.grid()
plt.show()

# %%
# double inPhase
plt.plot(inpDouble, color=(1.0, 0.5, 0.0))
plt.grid()
plt.show()

# %%
# x86 inPhase float
plt.plot(inpX86float[:500], color=(0, 0, 0))
plt.grid()
plt.show()

# %%
# x86 inPhase double
plt.plot(inpX86double[:500], color=(0, 1, 0))
plt.grid()
plt.show()

# %%
# float quadrature
plt.plot(quadFloat[:500], 'b-')
plt.grid()
plt.show()

# %%
# double quadrature
plt.plot(quadDouble, color=(1.0, 0.0, 1.0))
plt.grid()
plt.show()

# %%
# x86 quadrature float
plt.plot(quadX86float[:500], color=(0, 0, 0))
plt.grid()
plt.show()

# %%
# x86 quadrature double
plt.plot(quadX86double[:500], color=(0, 1, 0))
plt.grid()
plt.show()
